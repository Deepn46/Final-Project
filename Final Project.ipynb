# %% [markdown]
# Admin will have the following functionalities:
#
# Add new food items. Food Item will have the following details:
# FoodID //It should be generated automatically by the application.
# Name
# Quantity. For eg, 100ml, 250gm, 4pieces etc
# Price
# Discount
# Stock. Amount left in stock in the restaurant.
# Edit food items using FoodID.
# View the list of all food items.
# Remove a food item from the menu using FoodID.

# %%
import random
class admin:
    def __init__(self):
        self.food_items={}
        self.food_id=[]
        self.food_name=[]
       # self.zp=list(zip(self.food_id,self.food_name))
        self.zp=[]
    
    def create_food_items(self):
        
        print("\n            FOOD ITEM CREATION PAGE                ")
        
        
        
        nu=int(input("\n How many food items do you want to add "))
        for i in range(nu):
            a=input("\n Enter name of the food ")
            self.food_name.append(a)
            b=random.randint(10,99)
            self.food_id.append(b)
            print("\n Food id appended in self.food_id sucessfully")
            u=int(input("\n Enter the followings according to the requirement of units for quantity \n 1- ml \n 2- gm \n 3- pieces"))
            if u==1:
                unit="ml"
            elif u==2:
                unit="gm"
            elif u==3:
                unit="piece"
            print("\n Enter the price of 1 ", unit)
            price=int(input())
            qty= int(input("\n Enter the quantity of the product "))
            #print("\n Enter the price of 1 ", unit)
            #price=int(input("\n Enter the price of 1 ",unit,"  "))
            #price=int(input())
            discount=int(input("\n Enter the percentange of discount for this product "))
            self.food_items[a]=[b,qty,unit,price,discount]            # self.food_items[a]=[b,qty,unit,price,discount] a-food name  # b-id 
                                                                  
            self.zp.append((b,a))
            print("\n Food item added sucessfully ")
            print("\n Total food items are : ",self.food_name)
            
            #for i in range(len(self.food_items)):
                #self.food_id.append(i[0])
            
         
        #for i in self.food_items: 
          #  a.append(i)
        #print("\n The list of food items available  ",a)
            
    def view_food_items(self): 
        empty={}
        
        
        #print("\n            FOOD ITEM VIEW PAGE                ")
        
        if self.food_items!=empty:
            
            print("\n            FOOD ITEM VIEW PAGE                ")
            
            print("\n The following are the combination of food id & their respective food name  ", self.zp)
            s=int(input("\n Enter the food - id to view the details "))
            if s in self.food_id:             # kodnsdn  {'dosa': [65, 50, 'piece', 50, 10], 'idly': [43, 50, 'piece', 5, 10]}
                select=int(input("\n Enter \n   1 - To see the details of the selected food item \n 2 - To see  the details of all items  "))
                if select==1:
                    #s=int(input("\n Enter the food - id to view the details "))
                   # list_id=[]


                    #if s in self.food_id:

                    for i in self.food_items:

                        if self.food_items[i][0]==s:
                            print("\n Food name : ",i)
                            print("   Food id : ",self.food_items[i][0])
                            print("   Quantity available : ", self.food_items[i][1] , self.food_items[i][2])
                            print("   Price per ",self.food_items[i][2]," is ",self.food_items[i][3])
                    #else:
                       # print("\n You had entered invalid food id ")

                if select==2:
                    sn=1
                    for i in self.food_items:
                        print("\n S.NO  ",sn,end="  ")
                        print("   Food name : ",i)
                        print("   Food id : ",self.food_items[i][0])
                        print("   Quantity available : ", self.food_items[i][1] , self.food_items[i][2])
                        print("   Price per ",self.food_items[i][2]," is ",self.food_items[i][3])
                        sn+=1

                else:
                    print("\n Invalid input ")

            else:
                print("\n You had entered invalid food id ") 

        else:
            print("\n You didn't create any food item yet ")
            
            
        
    def edit_food_items(self):
        
        empty={}
        
        if self.food_items!=empty:
        
        
            print("\n            FOOD ITEM EDITING PAGE                ")


            print("\n The following are the combination of food id & their respective food name  ", self.zp)


            s=int(input("\n Enter the food ID which you need to edit ")) 

            if s in self.food_id:


                s2=int(input("\n Enter \n 1 - To remove food item \n  2 - To change food name \n 3 - To change unit \n 4 - To change price \n 5 - To edit the discount rate \n 6 - To edit quantity"))

                if s2==1:
                    for i in list(self.food_items.keys()):
                        if self.food_items[i][0]==s:
                            self.food_items.pop(str(i))
                            self.food_id.remove(s)
                            self.food_name.remove(str(i))
                            self.zp.remove((s,i))      # self.zp.append((b,a))



                    print("\n"," ID - ",s,"  ",i,"  Removed sucessfully ")     #### key: food name {'idly': [18, 50, 'piece', 5, 10]}
        #####            
              #  if s2==2:
               #     n=input("\n Enter the new food name ")
                #    for i in self.food_items:
                 #       if self.food_items[i][0]==s     #### To rename food(ie key of dict),need to update in all 3 init variables

             ######

                if s2==2:
                    n=input("\n Enter the new food name ")
                    for i in list(self.food_items.keys()):
                        if self.food_items[i][0]==s:
                            nv=self.food_items[i]
                            #self.food_items[n]=nv             #         self.food_id=[]  ,,  self.food_name=[]
                            self.food_id.remove(s)
                            self.food_name.remove(i)
                            self.food_items.pop(i)
                            self.food_id.append(s)
                            self.food_name.append(i)
                            self.food_items[n]=nv
                            self.zp.remove((s,i))
                            self.zp.append((s,n))
                    print("\n Food name changed sucessfully ")



                if s2==3:
                    u1=int(input("\n Enter the followings according to the requirement of units  \n 1- ml \n 2- gm \n 3- pieces"))
                    if u1==1:
                        for j in list(self.food_items.keys()):
                            if self.food_items[j][0]==s:                   
                                self.food_items[j][2]="ml"
                        print("\n Unit changed sucessfully ")
                    if u1==2:
                        for k in list(self.food_items.keys()):
                            if self.food_items[k][0]==s:                   
                                self.food_items[k][2]="gm"  
                        print("\n Unit changed sucessfully ")

                    if u1==3:
                        for l in list(self.food_items.keys()):
                            if self.food_items[l][0]==s:                    
                                self.food_items[l][2]="piece" 
                        print("\n Unit changed sucessfully ")

                if s2==4:                 #### key: food name {'idly': [18, 50, 'piece', 5, 10]}
                    for i in list(self.food_items.keys()):
                        if self.food_items[i][0]==s:
                            p1=int(input("\n Enter the new price "))
                            self.food_items[i][3]=p1

                    print("\n Price changed sucessfully ")

                if s2==5:                 #### key: food name {'idly': [18, 50, 'piece', 5, 10]}
                    for i in list(self.food_items.keys()):
                        if self.food_items[i][0]==s:                
                            d1=int(input("\n Enter the new discount rate "))
                            self.food_items[i][4]=d1

                    print("\n Discount rate changed sucessfully ")

                if s2==6:
                    for i in list(self.food_items.keys()):
                        if self.food_items[i][0]==s:                
                            q1=int(input("\n Enter the new quantity "))
                            self.food_items[i][4]=q1 

                    print("\n Quantity changed sucessfully ")
                    
        else:
            print("\n You didn't create any food item yet ")                    

                
    def menu(self):        #edit_food_items,view_food_items,create_food_items
        
        while True:
            ch=int(input("Enter 1 - create_food_items , 2 - view_food_items , 3 - edit_food_items "))
            if ch==1:
                self.create_food_items()
            if ch==2:
                self.view_food_items()                
            if ch==3:
                self.edit_food_items()
                
                
class users(admin):
    
    def __init__(self):
        super().__init__()
        self.users={}
        self.user=[]
        self.order_details={}

    def user_register(self):
        numb=int(input("\n Enter your phone number to register  , it must be in 10 digits : "))
        if len(str(numb))==10:
            if numb not in self.users:
                name=input("\n Enter your full name :  ")
                mail=input("\n Enter your mail-id   :  ")
                addr=input("\n Enter your address   :  ")
                pas =input("\n Create your password :  ")
                self.user=[name,mail,addr,pas]
                self.users[numb]=self.user
                
                print("\n Account created sucessfully ")
                
            else:
                print("\n OOPS !!!...Number already exist ")
        else:
            print("\n Invalid input ")
                
    def user_login(self):  
        s=[]
        #v=[]
        nu=int(input("\n Enter your number : "))
        if nu in self.users:
            pa=input("\n Enter your password : ")
            if pa==self.users[nu][3]:
                
                print("\n Logged in sucessfully  ")
                
                ch=int(input("\n Enter \n 1 - New order \n 2 - Order history "))         #Food id -  37  .  Dosa  -   1  piece
                if ch==1:                                                                # 1. Tandoori Chicken (4 pieces) [INR 240]
                    print("                 * MENU CARD *                  ")
                    for i in self.food_items:
                        print("\n "," Food id - ",self.food_items[i][0],". ", i ,"( 1 ",self.food_items[i][2]," )","[ INR -",((self.food_items[i][3])-((self.food_items[i][3]/100)*self.food_items[i][4]))," ]")
                        
                    ch4=input("\n Enter the the food id to order food (please give space between each food id you enter ) ")
                    spl=list(ch4.split())
                    for m in spl:              # self.food_items[a]=[b,qty,unit,price,discount] a-food name  # b-id    ((self.food_items[i][3]/100)*self.food_items[i][4])
                       # s=[]
                        v=[]
                        #print(self.food_id,"--- s")                                              ((self.food_items[i][3])-((self.food_items[i][3]/100)*self.food_items[i][4]))
                        if int(m) in self.food_id:
                            for n in self.food_items:
                                if self.food_items[n][0]==int(m):
                                    print("\n Quantity available in ",n," is ",self.food_items[n][1])
                                    print("\n How many ",self.food_items[n][2]," do you need ")
                                    rq=int(input())
                                    if rq<=self.food_items[n][1]:
                                        print("Cost for ",rq," ",self.food_items[n][2]," = "," INR ",((self.food_items[i][3])-((self.food_items[i][3]/100)*self.food_items[i][4])) *rq )
                                        p=input(" If you want to conform this order then enter y ")
                                        if p=="Y" or "y":
                                            print("\n Your order conformed sucessfully ")
                                            v.append(m)   # id
                                            v.append(n)   # Food name
                                            v.append(rq)  # quantity                  ord_deta={}
                                            s.append(v)                       # #  [[id,fdnm,qty],[id,fdnm,qty]] ,self.order_details{v[s]}
                                            self.order_details[nu]=s        #v=["id","food name","quantity"] 
                                              # self.food_items[a]=[b,qty,unit,price,discount] a-food name  # b-id 
                                            self.food_items[n][1]-=rq
                                            print("\n *** Quantity reduced sucessfully *** to ",self.food_items[n][1])
                                            print("\n Sucessfulley appended in self.order_details as ",self.order_details)
                                    else:
                                        print("\n Sorry we are having only : ",self.food_items[n][1]," ",self.food_items[n][2])
                        else:
                            print(" \n You had entered invalid food id ")
                            
                                                                #a={7402:[[1,"hi"],[2,"bye"]]}
                                                                #a[7402].append([3,"cu"])
                                                                #a[7402][1]
                            
                       # try:
                          #  self.order_details[nu]=s
                            
                          #  print("\n Sucessfulley appended in self.order_details as ",self.order_details)
                       # except:
                           # pass
                            
                if ch==2:
                    if nu in self.order_details:     #{ 7402:[[id,fdnm,qty],[id,fdnm,qty]] }
                        
                        print("\n             YOUR ORDER HISTORY                 ")
                        for x in range(len(self.order_details[nu])):
                            print("\n Food ID - ",self.order_details[nu][x][0]," / ",end=" ")
                            print("Food name  - ",self.order_details[nu][x][1]," / ",end=" ")
                            print("Ordered Quantity   - ",self.order_details[nu][x][2])
                    else:
                        print(" \n You had no history of order  ")
                        
                else:
                    print("\n Invalid input ")
                        
            else:
                print("\n Wrong password !!! ")
        else:
            print("\n Enterted number doesn't exist ") 
            
    def user_update_profile(self):
        n1=int(input("\n Enter your number to login :  "))
        if n1 in self.users:
            pw=input("\n Enter your password : ")
            if pw==self.users[n1][3]:
                
                print("\n Logged in sucessfully  ") 
                
                ch6=input("\n Enter \n 1 - To Edit full name \n 2 - To Edit mail-id \n 3 - To Edit address \n 4 - To Edit password ")
                
                if ch6=="1":
                    self.users[n1][0]=input("\n Enter your new name : ")
                    print("\n Name changed sucessfully ")
                elif ch6=="2":
                    self.users[n1][1]=input("\n Enter your new mail-id : ")
                    print("\n Mail-id changed sucessfully ")                    
                elif ch6=="3":
                    self.users[n1][2]=input("\n Enter your new address : ")
                    print("\n Address changed sucessfully ") 
                elif ch6=="4":
                    self.users[n1][3]=input("\n Enter your new password : ")
                    print("  HIIIII ",self.users[n1])
                    print("\n Password changed sucessfully ")           # self.user=[name,mail,addr,pas]
                else:
                    print("\n You had entered wrong value ")
                    
       
            else:
                print("\n You had entered wrong password ")
        else:
            print("\n Number does not exist")
            
            
            
    def menu(self):   # user_register , user_login
        while True:
            ch=int(input("\n Enter \n 1 - create_food_items \n 2 - view_food_items \n 3 - edit_food_items \n 4 - user_registration \n 5 - user_login \n 6 - User_Update_Profile "))
            if ch==1:
                self.create_food_items()
            elif ch==2:
                self.view_food_items()                
            elif ch==3:
                self.edit_food_items()
            elif ch==4:
                self.user_register()
            elif ch==5:
                self.user_login()
            elif ch==6:
                self.user_update_profile()
            else:
                break
                
            
            
        
    
ad=users()
ad.menu()
# Out:
#  Enter
#  1 - create_food_items
#  2 - view_food_items
#  3 - edit_food_items
#  4 - user_registration
#  5 - user_login
#  6 - User_Update_Profile 1
#
#             FOOD ITEM CREATION PAGE
#
#  How many food items do you want to add 2
#
#  Enter name of the food Idly
#
#  Food id appended in self.food_id sucessfully
#
#  Enter the followings according to the requirement of units for quantity
#  1- ml
#  2- gm
#  3- pieces3
#
#  Enter the price of 1  piece
# 10
#
#  Enter the quantity of the product 100
#
#  Enter the percentange of discount for this product 20
#
#  Food item added sucessfully
#
#  Total food items are :  ['Idly']
#
#  Enter name of the food Dosa
#
#  Food id appended in self.food_id sucessfully
#
#  Enter the followings according to the requirement of units for quantity
#  1- ml
#  2- gm
#  3- pieces3
#
#  Enter the price of 1  piece
# 15
#
#  Enter the quantity of the product 25
#
#  Enter the percentange of discount for this product 25
#
# ...
